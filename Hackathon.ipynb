# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 

df=pd.read_csv("./C&T train dataset.csv")
df
# Out:
#      sno acc_info  duration_month credit_history purpose savings_acc  \
# 0      1      A11               6            A34     A43         A65
# 1      2      A12              48            A32     A43         A61
# 2      3      A14              12            A34     A46         A61
# 3      4      A11              42            A32     A42         A61
# 4      5      A11              24            A33     A40         A61
# ..   ...      ...             ...            ...     ...         ...
# 795  796      A14               9            A32     A42         A62
# 796  797      A11              18            A32     A41         A65
# 797  798      A14              12            A34     A42         A61
# 798  799      A14              24            A33     A40         A65
# 799  800      A12               9            A32     A40         A65
#
#     employment_st  poi personal_status gurantors  ...  property_type   age  \
# ...

# %%
df1=pd.read_csv("./C&T test dataset 1.csv")
df1
# Out:
#      sno acc_info  duration_month credit_history purpose savings_acc  \
# 0      1      A14              24            A34     A46         A61
# 1      2      A12              18            A34     A43         A61
# 2      3      A11              20            A34     A42         A61
# 3      4      A14              12            A34     A43         A65
# 4      5      A12              12            A32     A40         A65
# ..   ...      ...             ...            ...     ...         ...
# 195  196      A14              12            A32     A42         A61
# 196  197      A11              30            A32     A41         A61
# 197  198      A14              12            A32     A43         A61
# 198  199      A11              45            A32     A43         A61
# 199  200      A12              45            A34     A41         A62
#
#     employment_st  poi personal_status gurantors  resident_since  \
# 0             A75  4.0             A93      A101               4
# ...

# %%
df.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of      sno acc_info  duration_month credit_history purpose savings_acc  \
# 0      1      A11               6            A34     A43         A65
# 1      2      A12              48            A32     A43         A61
# 2      3      A14              12            A34     A46         A61
# 3      4      A11              42            A32     A42         A61
# 4      5      A11              24            A33     A40         A61
# ..   ...      ...             ...            ...     ...         ...
# 795  796      A14               9            A32     A42         A62
# 796  797      A11              18            A32     A41         A65
# 797  798      A14              12            A34     A42         A61
# 798  799      A14              24            A33     A40         A65
# 799  800      A12               9            A32     A40         A65
#
#     employment_st  poi personal_status gurantors  ...  property_type   age  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sno               800 non-null    int64
#  1   acc_info          800 non-null    object
#  2   duration_month    800 non-null    int64
#  3   credit_history    800 non-null    object
#  4   purpose           800 non-null    object
#  5   savings_acc       800 non-null    object
#  6   employment_st     792 non-null    object
#  7   poi               788 non-null    float64
#  8   personal_status   800 non-null    object
#  9   gurantors         792 non-null    object
#  10  resident_since    800 non-null    int64
#  11  property_type     800 non-null    object
#  12  age               796 non-null    float64
#  13  installment_type  800 non-null    object
#  14  housing_type      793 non-null    object
#  15  credits_no        800 non-null    int64
# ...

# %%
df.isna().sum()
# Out:
# sno                  0
# acc_info             0
# duration_month       0
# credit_history       0
# purpose              0
# savings_acc          0
# employment_st        8
# poi                 12
# personal_status      0
# gurantors            8
# resident_since       0
# property_type        0
# age                  4
# installment_type     0
# housing_type         7
# credits_no           0
# job_type             0
# liables              0
# telephone            0
# foreigner            0
# Group_no             0
# dtype: int64

# %%
df.describe()
# Out:
#             sno  duration_month         poi  resident_since         age  \
# count  800.0000       800.00000  788.000000      800.000000  796.000000
# mean   400.5000        20.65125    2.950508        2.841250   35.408291
# std    231.0844        12.15635    1.130084        1.106833   11.499101
# min      1.0000         4.00000    1.000000        1.000000   19.000000
# 25%    200.7500        12.00000    2.000000        2.000000   27.000000
# 50%    400.5000        18.00000    3.000000        3.000000   33.000000
# 75%    600.2500        24.00000    4.000000        4.000000   41.000000
# max    800.0000        72.00000    4.000000        4.000000   75.000000
#
#        credits_no     liables    Group_no
# count  800.000000  800.000000  800.000000
# mean     1.396250    1.147500    2.076250
# std      0.569773    0.354825    0.744062
# min      1.000000    1.000000    1.000000
# 25%      1.000000    1.000000    2.000000
# 50%      1.000000    1.000000    2.000000
# ...

# %%
df1.isna().sum()
# Out:
# sno                 0
# acc_info            0
# duration_month      0
# credit_history      0
# purpose             0
# savings_acc         0
# employment_st       5
# poi                 5
# personal_status     0
# gurantors           0
# resident_since      0
# property_type       0
# age                 2
# installment_type    0
# housing_type        8
# credits_no          0
# job_type            0
# liables             0
# telephone           0
# foreigner           0
# dtype: int64

# %%
df1.sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of      sno acc_info  duration_month credit_history purpose savings_acc  \
# 0      1      A14              24            A34     A46         A61
# 1      2      A12              18            A34     A43         A61
# 2      3      A11              20            A34     A42         A61
# 3      4      A14              12            A34     A43         A65
# 4      5      A12              12            A32     A40         A65
# ..   ...      ...             ...            ...     ...         ...
# 195  196      A14              12            A32     A42         A61
# 196  197      A11              30            A32     A41         A61
# 197  198      A14              12            A32     A43         A61
# 198  199      A11              45            A32     A43         A61
# 199  200      A12              45            A34     A41         A62
#
#     employment_st  poi personal_status gurantors  resident_since  \
# ...

# %%
df1.describe()
# Out:
#               sno  duration_month         poi  resident_since         age  \
# count  200.000000      200.000000  195.000000      200.000000  198.000000
# mean   100.500000       21.910000    2.974359        2.860000   36.106061
# std     57.879185       11.635671    1.081408        1.093792   11.053808
# min      1.000000        4.000000    1.000000        1.000000   20.000000
# 25%     50.750000       12.000000    2.000000        2.000000   28.000000
# 50%    100.500000       20.000000    3.000000        3.000000   33.000000
# 75%    150.250000       27.250000    4.000000        4.000000   43.000000
# max    200.000000       60.000000    4.000000        4.000000   68.000000
#
#        credits_no     liables
# count  200.000000  200.000000
# mean     1.450000    1.185000
# std      0.607739    0.389272
# min      1.000000    1.000000
# 25%      1.000000    1.000000
# 50%      1.000000    1.000000
# 75%      2.000000    1.000000
# max      4.000000    2.000000

# %%
df.iloc[[500]]
# Out:
#      sno acc_info  duration_month credit_history purpose savings_acc  \
# 500  501      A11              24            A32     A40         A61
#
#     employment_st  poi personal_status gurantors  ...  property_type   age  \
# 500           A72  4.0             A92      A101  ...           A122  27.0
#
#      installment_type housing_type credits_no  job_type liables  telephone  \
# 500              A143         A152          1      A173       1       A191
#
#     foreigner Group_no
# 500      A201        2
#
# [1 rows x 21 columns]

# %%
df1.iloc[[125]]
# Out:
#      sno acc_info  duration_month credit_history purpose savings_acc  \
# 125  126      A11              12            A31     A40         A61
#
#     employment_st  poi personal_status gurantors  resident_since  \
# 125           A72  4.0             A93      A101               2
#
#     property_type   age installment_type housing_type  credits_no job_type  \
# 125          A123  46.0             A141         A152           2     A173
#
#      liables telephone foreigner
# 125        1      A192      A201

# %%
sns.countplot(x=df["credit_history"])
# Out:
# <Axes: xlabel='credit_history', ylabel='count'>

# %%
sns.countplot(x=df1["credit_history"])
# Out:
# <Axes: xlabel='credit_history', ylabel='count'>

# %%
plt.figure(figsize=(10,8))
sns.histplot(data=df,x='savings_acc',bins=15,kde=True,color="red")
plt.title("Distribution of savings_acc")
plt.xlabel('savings_acc')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df,x='duration_month',bins=15,kde=True,color="green")
plt.title("Distribution duration_month")
plt.xlabel('duration_month')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
plt.figure(figsize=(10,5))
sns.histplot(data=df,x='credit_history',bins=15,kde=True,color="brown")
plt.title("Distribution of credit_history")
plt.xlabel('credit_history')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df1,x='duration_month',bins=15,kde=True,color="green")
plt.title("Distribution duration_month")
plt.xlabel('duration_month')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
plt.figure(figsize=(10,5))
sns.histplot(data=df,x='credit_history',bins=15,kde=True,color="brown")
plt.title("Distribution of credit_history")
plt.xlabel('credit_history')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df,x='duration_month',bins=15,kde=True,color="green")
plt.title("Distribution duration_month")
plt.xlabel('duration_month')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
plt.figure(figsize=(10,5))
sns.histplot(data=df1,x='credit_history',bins=15,kde=True,color="brown")
plt.title("Distribution of credit_history")
plt.xlabel('credit_history')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df1,x='duration_month',bins=15,kde=True,color="green")
plt.title("Distribution duration_month")
plt.xlabel('duration_month')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
plt.figure(figsize=(10,5))
sns.histplot(data=df1,x='credit_history',bins=15,kde=True,color="brown")
plt.title("Distribution of credit_history")
plt.xlabel('credit_history')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sno               200 non-null    int64
#  1   acc_info          200 non-null    object
#  2   duration_month    200 non-null    int64
#  3   credit_history    200 non-null    object
#  4   purpose           200 non-null    object
#  5   savings_acc       200 non-null    object
#  6   employment_st     195 non-null    object
#  7   poi               195 non-null    float64
#  8   personal_status   200 non-null    object
#  9   gurantors         200 non-null    object
#  10  resident_since    200 non-null    int64
#  11  property_type     200 non-null    object
#  12  age               198 non-null    float64
#  13  installment_type  200 non-null    object
#  14  housing_type      192 non-null    object
#  15  credits_no        200 non-null    int64
# ...

# %%
df1.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of      sno acc_info  duration_month credit_history purpose savings_acc  \
# 0      1      A14              24            A34     A46         A61
# 1      2      A12              18            A34     A43         A61
# 2      3      A11              20            A34     A42         A61
# 3      4      A14              12            A34     A43         A65
# 4      5      A12              12            A32     A40         A65
# ..   ...      ...             ...            ...     ...         ...
# 195  196      A14              12            A32     A42         A61
# 196  197      A11              30            A32     A41         A61
# 197  198      A14              12            A32     A43         A61
# 198  199      A11              45            A32     A43         A61
# 199  200      A12              45            A34     A41         A62
#
#     employment_st  poi personal_status gurantors  resident_since  \
# ...

# %%
df1.shape
# Out:
# (200, 20)

# %%
plt.scatter(df1["duration_month"],df1["credit_history"],color="black")
plt.xlabel("credit_history")
plt.ylabel("duration_month")
# Out:
# Text(0, 0.5, 'duration_month')

# %%
plt.figure(figsize=(10,4))
sns.histplot(data=df1,x='savings_acc',bins=15,kde=True,color="red")
plt.title("Distribution of savings_acc")
plt.xlabel('savings_acc')
plt.ylabel('Frequency')
plt.show()

# %%
sns.countplot(x=df["savings_acc"])
# Out:
# <Axes: xlabel='savings_acc', ylabel='count'>

# %%
plt.figure(figsize=(10,4))
sns.countplot(data=df1,x='savings_acc',color="red")
plt.title("Distribution of savings_acc")
plt.xlabel('savings_acc')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df,x='savings_acc',bins=15,kde=True,color="green")
plt.title("Distribution savings_acc")
plt.xlabel('savings_acc')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
plt.figure(figsize=(10,5))
sns.histplot(data=df,x='credit_history',bins=15,kde=True,color="blue")
plt.title("Distribution of credit_history")
plt.xlabel('credit_history')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
df_g=df.groupby('savings_acc')['credit_history'].apply(lambda x:x.mode().iloc[0]).reset_index()
df_g.columns=['savings_acc','credit_history']
df_g
# Out:
#   savings_acc credit_history
# 0         A61            A32
# 1         A62            A32
# 2         A63            A32
# 3         A64            A32
# 4         A65            A32

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df1,x='savings_acc',bins=15,kde=True,color="orange")
plt.title("Distribution savings_acc")
plt.xlabel('savings_acc')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
plt.figure(figsize=(10,5))
sns.histplot(data=df1,x='credit_history',bins=15,kde=True,color="skyblue")
plt.title("Distribution of credit_history")
plt.xlabel('credit_history')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.countplot(data=df,x='savings_acc',color="red")
plt.title("Distribution of savings_acc")
plt.xlabel('savings_acc')
plt.ylabel('Frequency')
plt.show()
